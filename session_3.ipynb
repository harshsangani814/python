# %% [markdown]
# ### pandas

# %%
import pandas as pd 
print(pd.__version__)
# Out:
# 2.0.3

# %%
import pandas as pd
import numpy as np 

ser=pd.Series()
print(ser)

data=np.array(['h', 'a','r','s','h'])
ser=pd.Series(data)
print(ser)
# Out:
# Series([], dtype: object)
# 0    h
# 1    a
# 2    r
# 3    s
# 4    h
# dtype: object

# %%
import pandas as pd
import numpy as np 

ser=pd.Series()
print(ser)

data=np.array(['hddd', 'add','rddd','sdd','hdd'])
ser=pd.Series(data)
print(ser)
# Out:
# Series([], dtype: object)
# 0    hddd
# 1     add
# 2    rddd
# 3     sdd
# 4     hdd
# dtype: object

# %%
import pandas as pd

ver= {"day1": 420, "day2": 380, "day3": 390}

a= pd.Series(ver, index = ["day1", "day2"])

print(a)
# Out:
# day1    420
# day2    380
# dtype: int64

# %%
import pandas as pd
data = pd.read_csv("airlines.csv")
print(data.describe)
# Out:
# <bound method NDFrame.describe of      Airport.Code                                       Airport.Name  \
# 0             ATL  Atlanta, GA: Hartsfield-Jackson Atlanta Intern...
# 1             BOS                    Boston, MA: Logan International
# 2             BWI  Baltimore, MD: Baltimore/Washington Internatio...
# 3             CLT     Charlotte, NC: Charlotte Douglas International
# 4             DCA  Washington, DC: Ronald Reagan Washington National
# ...           ...                                                ...
# 4403          SAN             San Diego, CA: San Diego International
# 4404          SEA          Seattle, WA: Seattle/Tacoma International
# 4405          SFO     San Francisco, CA: San Francisco International
# 4406          SLC   Salt Lake City, UT: Salt Lake City International
# 4407          TPA                     Tampa, FL: Tampa International
#
#      Time.Label  Time.Month Time.Month Name  Time.Year  \
# ...

# %%
lst=['Geeks','harsh','jita','jiya']
df=pd.DataFrame(lst)
print(df[0][0])
# Out:
# Geeks

# %%
data={'name':['harsh', 'harshit','akshay','darshit'],
      'age':['20','22','23','25']}
df=pd.DataFrame(data)
print(df)
# Out:
#       name age
# 0    harsh   2
# 1  harshit  22
# 2   akshay  23
# 3  darshit  25

# %%
info=pd.DataFrame({'p':[4,5,3,3],
      'q':[2,4,5,3],
      'r':[5,6,7,8],
      's':[5,6,7,8]},
index=['harsh', 'harshit','akshay','darshit'])

# %%
data=pd.read_csv("nba.csv",index_col="Name")

first=data['Age']
print(first)
# Out:
# Name
# Avery Bradley    25.0
# Jae Crowder      25.0
# John Holland     27.0
# R.J. Hunter      22.0
# Jonas Jerebko    29.0
#                  ...
# Shelvin Mack     26.0
# Raul Neto        24.0
# Tibor Pleiss     26.0
# Jeff Withey      26.0
# NaN               NaN
# Name: Age, Length: 458, dtype: float64

# %%
data=pd.read_csv("nba.csv",index_col="Name")

row2=data.iloc[3]
print(row2)
# Out:
# Team        Boston Celtics
# Number                28.0
# Position                SG
# Age                   22.0
# Height                 6-5
# Weight               185.0
# College      Georgia State
# Salary           1148640.0
# Name: R.J. Hunter, dtype: object

# %%
### Matplotlib Tutorial
import matplotlib.pyplot as plt

x=[1,2,3]
y=[3,6,7]

plt.plot(x,y)
plt.xlabel("x-axis")

plt.xlabel("y-axis")
plt.title("my first graph")
plt.show()

# %%
x=np.arange(0,10,0.1)
y=np.sin(x)

plt.figure(figsize=(6,4))
plt.plot(x,y)
plt.show()

# %%
x=np.array([0,1,2,3])
y=np.array([3,8,1,10])

plt.subplot(2,2,1)
plt.plot(x,y)


x=np.array([0,1,2,3])
y=np.array([10,20,30,40])

plt.subplot(2,2,2)
plt.plot(x,y)


x=np.array([0,1,2,3])
y=np.array([3,8,1,10])

plt.subplot(2,2,3)
plt.plot(x,y)


x=np.array([0,1,2,3])
y=np.array([2,4,6,10])

plt.subplot(2,2,4)
plt.plot(x,y)

# %%
ypoints=np.array([3,8,7,6,7,6])
plt.plot(ypoints, marker='*',color='blue',line=':')

plt.show()
